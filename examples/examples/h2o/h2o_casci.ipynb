# %%
from ase.build import molecule
from ase.optimize import LBFGS
from ase import units

# %%
from qmlearn.api.api4ase import QMLCalculator
from qmlearn.drivers.mol import QMMol
from qmlearn.model import QMModel
from qmlearn.io import read_images
from qmlearn.preprocessing import AtomsCreater, build_train_atoms, build_properties

# %%
# basis = 'cc-pvtz'
# xc = 'b3lyp'
# method = 'rks'
basis = '6-31g*'
xc = None
method = 'casci'

# %%
atoms = molecule('H2O')

# %%
refqmmol = QMMol(atoms = atoms, method = method, basis=basis, xc = xc)
atoms.calc = QMLCalculator(qmmodel = refqmmol, method = 'engine')

# %%
LBFGS(atoms).run(fmax=1E-5);
# Out:
# CASCI E = -76.2071030014018  E(CI) = -85.2953967705411  S^2 = 0.0000000
# CASCI E = -76.2071030014018  E(CI) = -85.2953967705411  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0000000000    -0.0032929000
# 1 H    -0.0000000000    -0.0024178420     0.0016464500
# 2 H     0.0000000000     0.0024178420     0.0016464500
# ----------------------------------------------
#        Step     Time          Energy         fmax
# LBFGS:    0 23:18:07    -2073.700898        0.1693
# CASCI E = -76.2071182210744  E(CI) = -85.261921541505  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0000000000     0.0010433893
# 1 H    -0.0000000000     0.0001561839    -0.0005216946
# 2 H    -0.0000000000    -0.0001561839    -0.0005216946
# ----------------------------------------------
# LBFGS:    1 23:28:52    -2073.701312        0.0537
# CASCI E = -76.2071192971177  E(CI) = -85.2675289204922  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0000000000     0.0002186982
# 1 H    -0.0000000000    -0.0002120566    -0.0001093491
# 2 H    -0.0000000000     0.0002120566    -0.0001093491
# ----------------------------------------------
# LBFGS:    2 23:39:35    -2073.701341        0.0123
# CASCI E = -76.2071195372142  E(CI) = -85.2681465464239  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0000000000     0.0000333487
# 1 H     0.0000000000    -0.0001991379    -0.0000166744
# 2 H     0.0000000000     0.0001991379    -0.0000166744
# ----------------------------------------------
# LBFGS:    3 23:50:16    -2073.701348        0.0103
# CASCI E = -76.2071197176888  E(CI) = -85.2675560725392  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0000000000    -0.0000599546
# 1 H    -0.0000000000    -0.0000581072     0.0000299773
# 2 H     0.0000000000     0.0000581072     0.0000299773
# ----------------------------------------------
# LBFGS:    4 00:01:02    -2073.701352        0.0034
# CASCI E = -76.207119726159  E(CI) = -85.2670615674409  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0000000000    -0.0000164352
# 1 H     0.0000000000    -0.0000089559     0.0000082176
# 2 H    -0.0000000000     0.0000089559     0.0000082176
# ----------------------------------------------
# LBFGS:    5 00:11:48    -2073.701353        0.0008
# CASCI E = -76.2071197265198  E(CI) = -85.2669424871711  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0000000000    -0.0000008117
# 1 H    -0.0000000000    -0.0000000324     0.0000004059
# 2 H     0.0000000000     0.0000000324     0.0000004059
# ----------------------------------------------
# LBFGS:    6 00:22:34    -2073.701353        0.0000
# CASCI E = -76.2071197265244  E(CI) = -85.2669391298808  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0000000000    -0.0000000143
# 1 H     0.0000000000     0.0000000173     0.0000000071
# 2 H     0.0000000000    -0.0000000173     0.0000000071
# ----------------------------------------------
# LBFGS:    7 00:33:20    -2073.701353        0.0000

# %%
refqmmol = QMMol(atoms = atoms, method = method, basis=basis, xc = xc)
atoms.calc = QMLCalculator(qmmodel = refqmmol, method = 'engine', properties=('dipole',))

# %%
from ase.vibrations import Infrared

ir = Infrared(atoms, nfree=4)
ir.run()
ir.summary()
# Out:
# CASCI E = -76.2071197265243  E(CI) = -85.2669391298807  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0000000000    -0.0000000143
# 1 H     0.0000000000     0.0000000173     0.0000000071
# 2 H     0.0000000000    -0.0000000173     0.0000000071
# ----------------------------------------------
# CASCI E = -76.2071197211511  E(CI) = -85.2664776161724  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000011836    -0.0000000000     0.0000708088
# 1 H     0.0000005918     0.0000287736    -0.0000354044
# 2 H     0.0000005918    -0.0000287736    -0.0000354044
# ----------------------------------------------
# CASCI E = -76.2071196379596  E(CI) = -85.265093447801  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000094624     0.0000000000     0.0002830331
# 1 H     0.0000047312     0.0001149329    -0.0001415165
# 2 H     0.0000047312    -0.0001149329    -0.0001415165
# ----------------------------------------------
# CASCI E = -76.2071197211511  E(CI) = -85.2664776161724  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000011836     0.0000000000     0.0000708088
# 1 H    -0.0000005918     0.0000287736    -0.0000354044
# 2 H    -0.0000005918    -0.0000287736    -0.0000354044
# ----------------------------------------------
# CASCI E = -76.2071196379596  E(CI) = -85.265093447801  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000094624     0.0000000000     0.0002830331
# 1 H    -0.0000047312     0.0001149329    -0.0001415165
# 2 H    -0.0000047312    -0.0001149329    -0.0001415165
# ----------------------------------------------
# CASCI E = -76.2070041154027  E(CI) = -85.2672216714994  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0122364003    -0.0003137304
# 1 H    -0.0000000000     0.0059889987    -0.0046258903
# 2 H    -0.0000000000     0.0062474016     0.0049396207
# ----------------------------------------------
# CASCI E = -76.2066571991654  E(CI) = -85.2680689002698  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0244815638    -0.0012554596
# 1 H    -0.0000000000     0.0117240657    -0.0089535049
# 2 H    -0.0000000000     0.0127574981     0.0102089645
# ----------------------------------------------
# CASCI E = -76.2070041154027  E(CI) = -85.2672216714994  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0122364003    -0.0003137304
# 1 H    -0.0000000000    -0.0062474016     0.0049396207
# 2 H    -0.0000000000    -0.0059889987    -0.0046258903
# ----------------------------------------------
# CASCI E = -76.2066571991654  E(CI) = -85.2680689002698  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0244815638    -0.0012554596
# 1 H     0.0000000000    -0.0127574981     0.0102089645
# 2 H     0.0000000000    -0.0117240657    -0.0089535049
# ----------------------------------------------
# CASCI E = -76.207039118347  E(CI) = -85.32214055626  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0000000000    -0.0085541011
# 1 H     0.0000000000    -0.0035446897     0.0042770505
# 2 H    -0.0000000000     0.0035446897     0.0042770505
# ----------------------------------------------
# CASCI E = -76.2067954481786  E(CI) = -85.377285692349  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0000000000    -0.0172556332
# 1 H    -0.0000000000    -0.0072991920     0.0086278166
# 2 H    -0.0000000000     0.0072991920     0.0086278166
# ----------------------------------------------
# CASCI E = -76.2070401795703  E(CI) = -85.2117041990022  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0000000000     0.0083933687
# 1 H     0.0000000000     0.0033404888    -0.0041966844
# 2 H     0.0000000000    -0.0033404888    -0.0041966844
# ----------------------------------------------
# CASCI E = -76.2068036027558  E(CI) = -85.1564577873638  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0000000000     0.0166165681
# 1 H    -0.0000000000     0.0064826922    -0.0083082840
# 2 H    -0.0000000000    -0.0064826922    -0.0083082840
# ----------------------------------------------
# CASCI E = -76.207119724194  E(CI) = -85.2667010035998  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000005026    -0.0000399416     0.0000289270
# 1 H    -0.0000005068     0.0000391253    -0.0000300685
# 2 H     0.0000000042     0.0000008163     0.0000011415
# ----------------------------------------------
# CASCI E = -76.2071196884889  E(CI) = -85.2659868187842  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000040185    -0.0001596426     0.0001156548
# 1 H    -0.0000040511     0.0001563272    -0.0001201990
# 2 H     0.0000000327     0.0000033155     0.0000045443
# ----------------------------------------------
# CASCI E = -76.2071197241939  E(CI) = -85.2667010035997  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000005026    -0.0000399416     0.0000289270
# 1 H     0.0000005068     0.0000391253    -0.0000300685
# 2 H    -0.0000000042     0.0000008163     0.0000011415
# ----------------------------------------------
# CASCI E = -76.2071196884889  E(CI) = -85.2659868187841  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000040185    -0.0001596426     0.0001156548
# 1 H     0.0000040511     0.0001563272    -0.0001201990
# 2 H    -0.0000000327     0.0000033155     0.0000045443
# ----------------------------------------------
# CASCI E = -76.2070553671397  E(CI) = -85.3046819546209  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0062474816    -0.0035926656
# 1 H     0.0000000000    -0.0068577086     0.0042650482
# 2 H    -0.0000000000     0.0006102270    -0.0006723827
# ----------------------------------------------
# CASCI E = -76.2068587627873  E(CI) = -85.3427217645316  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0127580156    -0.0074978990
# 1 H    -0.0000000000    -0.0139969761     0.0088490245
# 2 H    -0.0000000000     0.0012389605    -0.0013511255
# ----------------------------------------------
# CASCI E = -76.2070571157465  E(CI) = -85.2294969690508  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0059890620     0.0032950387
# 1 H    -0.0000000000     0.0065811625    -0.0039615318
# 2 H     0.0000000000    -0.0005921005     0.0006664930
# ----------------------------------------------
# CASCI E = -76.2068727081788  E(CI) = -85.1923587513171  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0117245618     0.0063094207
# 1 H     0.0000000000     0.0128911062    -0.0076356813
# 2 H    -0.0000000000    -0.0011665444     0.0013262607
# ----------------------------------------------
# CASCI E = -76.2070822922796  E(CI) = -85.2393166338907  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0046705362     0.0042009679
# 1 H    -0.0000000000     0.0040066377    -0.0039514093
# 2 H     0.0000000000     0.0006638985    -0.0002495585
# ----------------------------------------------
# CASCI E = -76.2069708758875  E(CI) = -85.2116781935661  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0091250353     0.0083236557
# 1 H    -0.0000000000     0.0078078644    -0.0078288986
# 2 H    -0.0000000000     0.0013171709    -0.0004947570
# ----------------------------------------------
# CASCI E = -76.2070818333638  E(CI) = -85.2945348842154  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0048910612    -0.0042734126
# 1 H     0.0000000000    -0.0042166262     0.0040200827
# 2 H     0.0000000000    -0.0006744350     0.0002533299
# ----------------------------------------------
# CASCI E = -76.2069673645626  E(CI) = -85.3220927120224  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0100068134    -0.0086137355
# 1 H    -0.0000000000    -0.0086477089     0.0081035269
# 2 H     0.0000000000    -0.0013591045     0.0005102085
# ----------------------------------------------
# CASCI E = -76.207119724194  E(CI) = -85.2667010035998  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000005026     0.0000399416     0.0000289270
# 1 H     0.0000000042    -0.0000008163     0.0000011415
# 2 H    -0.0000005068    -0.0000391253    -0.0000300685
# ----------------------------------------------
# CASCI E = -76.2071196884889  E(CI) = -85.2659868187842  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000040185     0.0001596426     0.0001156548
# 1 H     0.0000000327    -0.0000033155     0.0000045443
# 2 H    -0.0000040511    -0.0001563272    -0.0001201990
# ----------------------------------------------
# CASCI E = -76.207119724194  E(CI) = -85.2667010035998  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000005026     0.0000399416     0.0000289270
# 1 H    -0.0000000042    -0.0000008163     0.0000011415
# 2 H     0.0000005068    -0.0000391253    -0.0000300685
# ----------------------------------------------
# CASCI E = -76.2071196884888  E(CI) = -85.2659868187841  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000040185     0.0001596426     0.0001156548
# 1 H    -0.0000000327    -0.0000033155     0.0000045443
# 2 H     0.0000040511    -0.0001563272    -0.0001201990
# ----------------------------------------------
# CASCI E = -76.2070571157465  E(CI) = -85.2294969690508  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0059890620     0.0032950387
# 1 H    -0.0000000000     0.0005921005     0.0006664930
# 2 H    -0.0000000000    -0.0065811625    -0.0039615318
# ----------------------------------------------
# CASCI E = -76.2068727081787  E(CI) = -85.192358751317  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0117245618     0.0063094207
# 1 H    -0.0000000000     0.0011665444     0.0013262607
# 2 H    -0.0000000000    -0.0128911062    -0.0076356813
# ----------------------------------------------
# CASCI E = -76.2070553671397  E(CI) = -85.3046819546209  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0062474816    -0.0035926656
# 1 H     0.0000000000    -0.0006102270    -0.0006723827
# 2 H     0.0000000000     0.0068577086     0.0042650482
# ----------------------------------------------
# CASCI E = -76.2068587627873  E(CI) = -85.3427217645315  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0127580156    -0.0074978990
# 1 H    -0.0000000000    -0.0012389605    -0.0013511255
# 2 H    -0.0000000000     0.0139969761     0.0088490245
# ----------------------------------------------
# CASCI E = -76.2070822922795  E(CI) = -85.2393166338906  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0046705362     0.0042009679
# 1 H    -0.0000000000    -0.0006638985    -0.0002495585
# 2 H    -0.0000000000    -0.0040066377    -0.0039514093
# ----------------------------------------------
# CASCI E = -76.2069708758875  E(CI) = -85.2116781935661  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0091250353     0.0083236557
# 1 H    -0.0000000000    -0.0013171709    -0.0004947570
# 2 H    -0.0000000000    -0.0078078644    -0.0078288986
# ----------------------------------------------
# CASCI E = -76.2070818333638  E(CI) = -85.2945348842154  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0048910612    -0.0042734126
# 1 H    -0.0000000000     0.0006744350     0.0002533299
# 2 H     0.0000000000     0.0042166262     0.0040200827
# ----------------------------------------------
# CASCI E = -76.2069673645626  E(CI) = -85.3220927120224  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0100068134    -0.0086137355
# 1 H    -0.0000000000     0.0013591045     0.0005102085
# 2 H    -0.0000000000     0.0086477089     0.0081035269
# ----------------------------------------------
# -------------------------------------
#  Mode    Frequency        Intensity
#   #    meV     cm^-1   (D/Å)^2 amu^-1
# -------------------------------------
#   0    0.1i      0.7i     0.0866
#   1    0.0i      0.0i     0.0201
#   2    0.0i      0.0i     0.0000
#   3    0.1       0.8      7.3089
#   4    0.1       1.0      0.0000
#   5    0.5       3.8      2.4901
#   6  215.5    1738.3      2.0417
#   7  459.8    3708.4      0.0432
#   8  476.0    3838.9      0.5113
# -------------------------------------
# Zero-point energy: 0.576 eV
# Static dipole moment: 2.167 D
# Maximum force on atom in `equilibrium`: 0.0000 eV/Å

# %%
vib = ir.get_vibrations()
modes = vib.get_modes()
frequencies = vib.get_frequencies().real

# %%
random_seed = 8888
temperature = 300
nsamples = 27
tol = 0.04

# %%
creater = AtomsCreater(modes=modes, frequencies=frequencies, 
                       atoms=atoms, temperature=temperature,
                       random_seed=random_seed)

# %%
images = build_train_atoms(creater, nsamples=nsamples, tol=tol, refatoms=atoms)
# Out:
# Start build
# Get 27 samples at 32741 step.

# %%
prop = ['vext', 'gamma', 'energy', 'forces', 'dipole', 'ke']
properties = build_properties(images, refqmmol = refqmmol, properties=prop)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# CASCI E = -76.2071197265243  E(CI) = -85.2669391298807  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0000000000    -0.0000000143
# 1 H     0.0000000000     0.0000000173     0.0000000071
# 2 H    -0.0000000000    -0.0000000173     0.0000000071
# ----------------------------------------------
# CASCI E = -76.2014085082937  E(CI) = -85.2975549005062  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0565689617    -0.0349230423
# 1 H     0.0000000000    -0.0207405885     0.0359407417
# 2 H    -0.0000000000    -0.0358283732    -0.0010176994
# ----------------------------------------------
# CASCI E = -76.1957125168707  E(CI) = -85.4503101211651  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0159512721     0.0114803795
# 1 H     0.0000000000    -0.0548487854     0.0024938463
# 2 H     0.0000000000     0.0388975133    -0.0139742258
# ----------------------------------------------
# CASCI E = -76.1919884284914  E(CI) = -86.0640613206873  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0429443286    -0.1254371358
# 1 H    -0.0000000000    -0.1013908788     0.0786199151
# 2 H     0.0000000000     0.0584465501     0.0468172207
# ----------------------------------------------
# CASCI E = -76.1970647903455  E(CI) = -85.0445119212961  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0979049167    -0.0045332415
# 1 H     0.0000000000    -0.0346264734     0.0382022566
# 2 H    -0.0000000000    -0.0632784433    -0.0336690152
# ----------------------------------------------
# CASCI E = -76.1998256323161  E(CI) = -84.9960749588852  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0003794602     0.0625655922
# 1 H     0.0000000000    -0.0041579851    -0.0314578192
# 2 H     0.0000000000     0.0045374453    -0.0311077729
# ----------------------------------------------
# CASCI E = -76.2019750592081  E(CI) = -85.0027718970774  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0454800254     0.0419967128
# 1 H    -0.0000000000    -0.0165835026    -0.0016116804
# 2 H     0.0000000000    -0.0288965228    -0.0403850323
# ----------------------------------------------
# CASCI E = -76.1986807838395  E(CI) = -85.6592129659489  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0418922276    -0.0338421221
# 1 H     0.0000000000    -0.0322868258    -0.0029779227
# 2 H    -0.0000000000     0.0741790534     0.0368200449
# ----------------------------------------------
# CASCI E = -76.1976115577906  E(CI) = -84.7766704100324  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0027355256     0.0130316770
# 1 H    -0.0000000000     0.0519979248    -0.0073800106
# 2 H     0.0000000000    -0.0492623993    -0.0056516665
# ----------------------------------------------
# CASCI E = -76.1984950149181  E(CI) = -85.6018094177153  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0808602659    -0.0385369336
# 1 H     0.0000000000    -0.0855435447     0.0558386458
# 2 H     0.0000000000     0.0046832787    -0.0173017122
# ----------------------------------------------
# CASCI E = -76.1934695757438  E(CI) = -85.9238741822058  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0191776629    -0.1122179325
# 1 H     0.0000000000    -0.0666986295     0.0622341363
# 2 H     0.0000000000     0.0475209666     0.0499837962
# ----------------------------------------------
# CASCI E = -76.2008180706333  E(CI) = -84.7130584015854  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0020438889     0.0474276554
# 1 H     0.0000000000     0.0434631986    -0.0244529664
# 2 H    -0.0000000000    -0.0414193098    -0.0229746890
# ----------------------------------------------
# CASCI E = -76.1941815386716  E(CI) = -85.4159634921529  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.1362561899    -0.0460967229
# 1 H    -0.0000000000    -0.0934376479     0.0778885687
# 2 H    -0.0000000000    -0.0428185420    -0.0317918458
# ----------------------------------------------
# CASCI E = -76.1934284899966  E(CI) = -85.186581633868  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0603591291    -0.0443672216
# 1 H    -0.0000000000     0.0531344541     0.0054862072
# 2 H    -0.0000000000     0.0072246750     0.0388810144
# ----------------------------------------------
# CASCI E = -76.1909942036512  E(CI) = -85.1559628764237  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0802598903     0.0312977987
# 1 H    -0.0000000000    -0.0668637254     0.0245045379
# 2 H     0.0000000000    -0.0133961649    -0.0558023365
# ----------------------------------------------
# CASCI E = -76.189853696636  E(CI) = -84.8251519684566  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0186318334    -0.0162532729
# 1 H     0.0000000000     0.0449959922     0.0131789895
# 2 H    -0.0000000000    -0.0636278256     0.0030742833
# ----------------------------------------------
# CASCI E = -76.2003057218988  E(CI) = -85.1425234332604  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0836936977    -0.0114884506
# 1 H     0.0000000000     0.0530025008    -0.0244027099
# 2 H     0.0000000000     0.0306911969     0.0358911605
# ----------------------------------------------
# CASCI E = -76.196183150551  E(CI) = -84.5791403382973  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000     0.0299954810     0.0743721528
# 1 H     0.0000000000     0.0223713589    -0.0255550982
# 2 H    -0.0000000000    -0.0523668399    -0.0488170546
# ----------------------------------------------
# CASCI E = -76.1863991843055  E(CI) = -86.2130374197247  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0198556483    -0.1397994977
# 1 H    -0.0000000000    -0.1167350990     0.0786181901
# 2 H    -0.0000000000     0.0968794507     0.0611813076
# ----------------------------------------------
# CASCI E = -76.2009152703057  E(CI) = -85.3836502048858  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0821245267    -0.0143968408
# 1 H    -0.0000000000     0.0188864591    -0.0281052528
# 2 H    -0.0000000000     0.0632380676     0.0425020936
# ----------------------------------------------
# CASCI E = -76.1908279701608  E(CI) = -85.6848729587648  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0712371755    -0.0938595366
# 1 H    -0.0000000000    -0.0634280546     0.0665616171
# 2 H    -0.0000000000    -0.0078091209     0.0272979194
# ----------------------------------------------
# CASCI E = -76.1912110601087  E(CI) = -85.1797947209255  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.1040830424    -0.0460972997
# 1 H    -0.0000000000    -0.0357404975     0.0535494994
# 2 H     0.0000000000    -0.0683425448    -0.0074521997
# ----------------------------------------------
# CASCI E = -76.1975856953026  E(CI) = -85.4285402738427  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0776315269    -0.0579695532
# 1 H     0.0000000000     0.0347534947     0.0049234687
# 2 H     0.0000000000     0.0428780322     0.0530460845
# ----------------------------------------------
# CASCI E = -76.1857809028324  E(CI) = -84.35602343336  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000     0.0041506041     0.1188460636
# 1 H    -0.0000000000     0.0263739305    -0.0577439015
# 2 H    -0.0000000000    -0.0305245345    -0.0611021621
# ----------------------------------------------
# CASCI E = -76.1914982260081  E(CI) = -84.5775950223944  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0578209138     0.0350202594
# 1 H    -0.0000000000     0.0799859865    -0.0372335231
# 2 H    -0.0000000000    -0.0221650727     0.0022132637
# ----------------------------------------------
# CASCI E = -76.1875972085762  E(CI) = -84.8058890295734  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O    -0.0000000000    -0.0179370818     0.0948322995
# 1 H     0.0000000000    -0.0026897259    -0.0562505773
# 2 H     0.0000000000     0.0206268077    -0.0385817222
# ----------------------------------------------
# CASCI E = -76.1921210959471  E(CI) = -85.1401629812137  S^2 = 0.0000000
# --------- CASCI gradients for state 0 ----------
#          x                y                z
# 0 O     0.0000000000    -0.0842689828     0.0288637301
# 1 H    -0.0000000000     0.0195942399    -0.0555820326
# 2 H     0.0000000000     0.0646747429     0.0267183024
# ----------------------------------------------

# %%
from qmlearn.io import write_db
write_db('h2o_300_0.040_27_casci_qmldb.hdf5', refqmmol, images, properties)
# Out:
# ['casci', 'casci/qmmol', 'casci/train_atoms_27', 'casci/train_props_27']

# %%
from qmlearn.io import DBHDF5
fh = DBHDF5('./h2o_300_0.040_27_casci_qmldb.hdf5')
qmmol = fh.read_qmmol(fh.get_names('*/qmmol*')[0])
atoms = qmmol.atoms
fh.close()

# %%
atoms.write('opt-casci.xyz', format='xyz')
